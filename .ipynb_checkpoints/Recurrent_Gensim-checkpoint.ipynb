# %%
import numpy as np
import pandas as pd
import requests
import json
import urllib
import tensorflow as tf
import tensorflow_datasets
from tensorflow import keras
from gensim.models.callbacks import CallbackAny2Vec
# %config Completer.use_jedi =False
from gensim.models import Word2Vec

# %%
embedded_picks=np.load('embedding_array_30.npy')
picks_array=np.load('picks_array.npy')
names_array=np.load('names_array.npy')

# %%
names_array.shape
# Out:
# (34877, 10)

# %%
picks_array
# Out:
# array([[105,   4, 119,  67,  68],
#        [108,  36,  19,   5,  18],
#        [ 62,  49,  34,  23,   5],
#        ...,
#        [ 72,  11, 110, 116,  94],
#        [  2,   8,  51,  40,  36],
#        [119,   8,   2,  95, 112]])

# %%
test_start=embedded_picks.shape[0]-int(0.05*embedded_picks.shape[0])
cv_start=test_start-int(0.1*embedded_picks.shape[0])
test_picks=embedded_picks[test_start:]
testlabel_picks=picks_array[test_start:]
cv_picks=embedded_picks[cv_start:test_start]
cvlabel_picks=picks_array[cv_start:test_start]
train_picks=embedded_picks[:cv_start]
tlabel_picks=picks_array[:cv_start]
tlabel_picks=tlabel_picks.reshape((tlabel_picks.shape[0],tlabel_picks.shape[1],1))
one_labels=tf.one_hot(tlabel_picks,depth=120)
one_labels=tf.reshape(one_labels,(tlabel_picks.shape[0],tlabel_picks.shape[1],120))
one_cvlabels=tf.one_hot(cvlabel_picks,depth=120)
one_cvlabels=tf.reshape(one_cvlabels,(cvlabel_picks.shape[0],cvlabel_picks.shape[1],120))
one_testlabels=tf.one_hot(testlabel_picks,depth=120)
one_testlabels=tf.reshape(one_testlabels,(testlabel_picks.shape[0],testlabel_picks.shape[1],120))
hero_df=pd.read_csv('heroes.csv')
hero_dict={}
for i in hero_df['sid']:
    hero_dict[i]=hero_df[hero_df['sid']==i]['localized_name'].values[0]
embed_df=pd.read_csv('hero_to_embedding.csv')
embed_df.set_index('Heroes',inplace=True)

# %%
hero_dict
# Out:
# {0: 'Anti-Mage',
#  1: 'Axe',
#  2: 'Bane',
#  3: 'Bloodseeker',
#  4: 'Crystal Maiden',
#  5: 'Drow Ranger',
#  6: 'Earthshaker',
#  7: 'Juggernaut',
#  8: 'Mirana',
#  9: 'Morphling',
#  10: 'Shadow Fiend',
#  11: 'Phantom Lancer',
#  12: 'Puck',
#  13: 'Pudge',
#  14: 'Razor',
#  15: 'Sand King',
#  16: 'Storm Spirit',
#  17: 'Sven',
#  18: 'Tiny',
#  19: 'Vengeful Spirit',
#  20: 'Windranger',
#  21: 'Zeus',
#  22: 'Kunkka',
#  23: 'Lina',
#  24: 'Lion',
#  25: 'Shadow Shaman',
#  26: 'Slardar',
#  27: 'Tidehunter',
#  28: 'Witch Doctor',
#  29: 'Lich',
#  30: 'Riki',
#  31: 'Enigma',
#  32: 'Tinker',
#  33: 'Sniper',
#  34: 'Necrophos',
#  35: 'Warlock',
#  36: 'Beastmaster',
#  37: 'Queen of Pain',
#  38: 'Venomancer',
#  39: 'Faceless Void',
#  40: 'Wraith King',
#  41: 'Death Prophet',
#  42: 'Phantom Assassin',
#  43: 'Pugna',
#  44: 'Templar Assassin',
#  45: 'Viper',
#  46: 'Luna',
#  47: 'Dragon Knight',
#  48: 'Dazzle',
#  49: 'Clockwerk',
#  50: 'Leshrac',
#  51: "Nature's Prophet",
#  52: 'Lifestealer',
#  53: 'Dark Seer',
#  54: 'Clinkz',
#  55: 'Omniknight',
#  56: 'Enchantress',
#  57: 'Huskar',
#  58: 'Night Stalker',
#  59: 'Broodmother',
#  60: 'Bounty Hunter',
#  61: 'Weaver',
#  62: 'Jakiro',
#  63: 'Batrider',
#  64: 'Chen',
#  65: 'Spectre',
#  66: 'Ancient Apparition',
#  67: 'Doom',
#  68: 'Ursa',
#  69: 'Spirit Breaker',
#  70: 'Gyrocopter',
#  71: 'Alchemist',
#  72: 'Invoker',
#  73: 'Silencer',
#  74: 'Outworld Destroyer',
#  75: 'Lycan',
#  76: 'Brewmaster',
#  77: 'Shadow Demon',
#  78: 'Lone Druid',
#  79: 'Chaos Knight',
#  80: 'Meepo',
#  81: 'Treant Protector',
#  82: 'Ogre Magi',
#  83: 'Undying',
#  84: 'Rubick',
#  85: 'Disruptor',
#  86: 'Nyx Assassin',
#  87: 'Naga Siren',
#  88: 'Keeper of the Light',
#  89: 'Io',
#  90: 'Visage',
#  91: 'Slark',
#  92: 'Medusa',
#  93: 'Troll Warlord',
#  94: 'Centaur Warrunner',
#  95: 'Magnus',
#  96: 'Timbersaw',
#  97: 'Bristleback',
#  98: 'Tusk',
#  99: 'Skywrath Mage',
#  100: 'Abaddon',
#  101: 'Elder Titan',
#  102: 'Legion Commander',
#  103: 'Techies',
#  104: 'Ember Spirit',
#  105: 'Earth Spirit',
#  106: 'Underlord',
#  107: 'Terrorblade',
#  108: 'Phoenix',
#  109: 'Oracle',
#  110: 'Winter Wyvern',
#  111: 'Arc Warden',
#  112: 'Monkey King',
#  113: 'Dark Willow',
#  114: 'Pangolier',
#  115: 'Grimstroke',
#  116: 'Hoodwink',
#  117: 'Void Spirit',
#  118: 'Snapfire',
#  119: 'Mars'}

# %%
def pipe(arr,labels):
    data=tf.data.Dataset.from_tensor_slices(arr)
    vals=tf.data.Dataset.from_tensor_slices(labels)
    combined=tf.data.Dataset.zip((data,vals))
    finale=combined.map(lambda x,y: (x[:-1],y[-1]))
    return finale
def preds(arr):
    if len(arr.shape)!=2:
        data=tf.data.Dataset.from_tensor_slices(arr)
        data=data.map(lambda x: x[:-1])
        data=data.batch(1,drop_remainder=True)
    else:
        data=np.reshape(arr,(1,arr.shape[0],arr.shape[1]))
        data=tf.data.Dataset.from_tensor_slices(data)
        data=data.map(lambda x: x[:-1])
        data=data.batch(1,drop_remainder=True)
    return data

# %%
train=pipe(train_picks,one_labels)
train=train.batch(32,drop_remainder=True)
cv=pipe(cv_picks,one_cvlabels)
cv=cv.batch(1,drop_remainder=True)
test=pipe(test_picks,one_testlabels)
test=test.batch(1,drop_remainder=True)

# %%
model=keras.models.Sequential([
    keras.layers.LSTM(128,recurrent_dropout=0.1,return_sequences=True,input_shape=[None,25]),
    keras.layers.LSTM(128,recurrent_dropout=0.1),
    keras.layers.Dense(120,activation='softmax')
])
model.compile(loss='categorical_crossentropy',optimizer="adam",metrics=['accuracy'])
history=model.fit(train,epochs=50,validation_data=cv)
model.save('lstm128_25.h5')
# Out:
# Epoch 1/50
# 1083/1083 [==============================] - 12s 8ms/step - loss: 4.3218 - accuracy: 0.0392 - val_loss: 4.1353 - val_accuracy: 0.0404
# Epoch 2/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 4.0988 - accuracy: 0.0471 - val_loss: 4.1144 - val_accuracy: 0.0414
# Epoch 3/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 4.0643 - accuracy: 0.0513 - val_loss: 4.1035 - val_accuracy: 0.0419
# Epoch 4/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 4.0365 - accuracy: 0.0541 - val_loss: 4.1018 - val_accuracy: 0.0453
# Epoch 5/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 4.0069 - accuracy: 0.0561 - val_loss: 4.1025 - val_accuracy: 0.0468
# Epoch 6/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.9734 - accuracy: 0.0605 - val_loss: 4.1083 - val_accuracy: 0.0471
# Epoch 7/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.9331 - accuracy: 0.0650 - val_loss: 4.1190 - val_accuracy: 0.0480
# Epoch 8/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.8864 - accuracy: 0.0709 - val_loss: 4.1402 - val_accuracy: 0.0449
# Epoch 9/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.8320 - accuracy: 0.0808 - val_loss: 4.1656 - val_accuracy: 0.0488
# Epoch 10/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.7760 - accuracy: 0.0910 - val_loss: 4.1942 - val_accuracy: 0.0458
# Epoch 11/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.7150 - accuracy: 0.0992 - val_loss: 4.2288 - val_accuracy: 0.0439
# Epoch 12/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.6491 - accuracy: 0.1117 - val_loss: 4.2635 - val_accuracy: 0.0453
# Epoch 13/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.5860 - accuracy: 0.1196 - val_loss: 4.3022 - val_accuracy: 0.0424
# Epoch 14/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.5198 - accuracy: 0.1298 - val_loss: 4.3372 - val_accuracy: 0.0422
# Epoch 15/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.4522 - accuracy: 0.1461 - val_loss: 4.3854 - val_accuracy: 0.0417
# Epoch 16/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.3821 - accuracy: 0.1588 - val_loss: 4.4213 - val_accuracy: 0.0409
# Epoch 17/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.3170 - accuracy: 0.1705 - val_loss: 4.4696 - val_accuracy: 0.0392
# Epoch 18/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.2564 - accuracy: 0.1838 - val_loss: 4.5146 - val_accuracy: 0.0390
# Epoch 19/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.1849 - accuracy: 0.2021 - val_loss: 4.5622 - val_accuracy: 0.0348
# Epoch 20/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.1231 - accuracy: 0.2134 - val_loss: 4.6220 - val_accuracy: 0.0370
# Epoch 21/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 3.0749 - accuracy: 0.2193 - val_loss: 4.6713 - val_accuracy: 0.0328
# Epoch 22/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 3.0148 - accuracy: 0.2355 - val_loss: 4.7177 - val_accuracy: 0.0343
# Epoch 23/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 2.9559 - accuracy: 0.2452 - val_loss: 4.7632 - val_accuracy: 0.0355
# Epoch 24/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 2.9062 - accuracy: 0.2583 - val_loss: 4.8225 - val_accuracy: 0.0338
# Epoch 25/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 2.8624 - accuracy: 0.2675 - val_loss: 4.8769 - val_accuracy: 0.0350
# Epoch 26/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 2.8151 - accuracy: 0.2737 - val_loss: 4.9223 - val_accuracy: 0.0346
# Epoch 27/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 2.7644 - accuracy: 0.2867 - val_loss: 4.9699 - val_accuracy: 0.0365
# Epoch 28/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 2.7192 - accuracy: 0.2938 - val_loss: 5.0136 - val_accuracy: 0.0333
# Epoch 29/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 2.6834 - accuracy: 0.3064 - val_loss: 5.0700 - val_accuracy: 0.0336
# Epoch 30/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 2.6509 - accuracy: 0.3101 - val_loss: 5.1107 - val_accuracy: 0.0346
# Epoch 31/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 2.6081 - accuracy: 0.3200 - val_loss: 5.1749 - val_accuracy: 0.0333
# Epoch 32/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 2.5643 - accuracy: 0.3290 - val_loss: 5.2116 - val_accuracy: 0.0328
# Epoch 33/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 2.5332 - accuracy: 0.3317 - val_loss: 5.2457 - val_accuracy: 0.0346
# Epoch 34/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 2.5105 - accuracy: 0.3393 - val_loss: 5.2822 - val_accuracy: 0.0326
# Epoch 35/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 2.4615 - accuracy: 0.3464 - val_loss: 5.3507 - val_accuracy: 0.0338
# Epoch 36/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 2.4481 - accuracy: 0.3488 - val_loss: 5.4006 - val_accuracy: 0.0326
# Epoch 37/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 2.4137 - accuracy: 0.3571 - val_loss: 5.4557 - val_accuracy: 0.0328
# Epoch 38/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 2.3914 - accuracy: 0.3609 - val_loss: 5.4978 - val_accuracy: 0.0363
# Epoch 39/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 2.3587 - accuracy: 0.3665 - val_loss: 5.5486 - val_accuracy: 0.0355
# Epoch 40/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 2.3248 - accuracy: 0.3770 - val_loss: 5.5878 - val_accuracy: 0.0348
# Epoch 41/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 2.3047 - accuracy: 0.3781 - val_loss: 5.6164 - val_accuracy: 0.0348
# Epoch 42/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 2.2807 - accuracy: 0.3818 - val_loss: 5.6666 - val_accuracy: 0.0326
# Epoch 43/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 2.2626 - accuracy: 0.3887 - val_loss: 5.6997 - val_accuracy: 0.0360
# Epoch 44/50
# 1083/1083 [==============================] - 8s 8ms/step - loss: 2.2414 - accuracy: 0.3951 - val_loss: 5.7295 - val_accuracy: 0.0365
# Epoch 45/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 2.2271 - accuracy: 0.3973 - val_loss: 5.7808 - val_accuracy: 0.0358
# Epoch 46/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 2.1887 - accuracy: 0.4014 - val_loss: 5.8179 - val_accuracy: 0.0360
# Epoch 47/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 2.1718 - accuracy: 0.4053 - val_loss: 5.8490 - val_accuracy: 0.0358
# Epoch 48/50
# 1083/1083 [==============================] - 10s 9ms/step - loss: 2.1569 - accuracy: 0.4121 - val_loss: 5.8761 - val_accuracy: 0.0348
# Epoch 49/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 2.1332 - accuracy: 0.4154 - val_loss: 5.9127 - val_accuracy: 0.0348
# Epoch 50/50
# 1083/1083 [==============================] - 9s 8ms/step - loss: 2.1232 - accuracy: 0.4130 - val_loss: 5.9371 - val_accuracy: 0.0363

# %%
model=keras.models.load_model('lstm128_25.h5')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 128)         78848
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense (Dense)                (None, 120)               15480
# =================================================================
# Total params: 225,912
# Trainable params: 225,912
# Non-trainable params: 0
# _________________________________________________________________

# %%
model=keras.models.load_model('lstm128_25.h5')
def predictions(arr):
    instance=[]
    label=embed_df.loc[arr].index[-1]
    for i in embed_df.loc[arr].index:
        instance.append(embed_df.loc[i][embed_df.columns].values)
#     print('First 4 picks are')
#     print(' ')
#     for i,j in enumerate(embed_df.loc[arr].index[:-1]):
#         print(str(i+1)+'.'+j)
    instance=np.array(instance)
    print(len(instance))
    instance=preds(instance)
    predictions=model.predict(instance)
#     ind=np.argpartition(predictions[0],-3)[-3:][::-1]
#     print(' ')
#     print('Suggestions are')
    
#     print(' ')
#     for i,j in enumerate(ind):
#         print(str(i+1)+'.'+hero_dict[j])
#     print(' ')
    
#     print('Actual Pick')
#     print(' ')
    
#     print(label)

# %%
predictions(names_array[3023])
# Out:
# 5

# %%
names_array[1]
# Out:
# array(['Phoenix', 'Beastmaster', 'Vengeful Spirit', 'Drow Ranger', 'Tiny'],
#       dtype='<U19')

# %%
def accuracy_computing(data):
    correct=0
    for i in data:
        instance=[]
        suggestions=[]
        label=embed_df.loc[i].index[-1]
        for i in embed_df.loc[i].index:
            instance.append(embed_df.loc[i][embed_df.columns].values)
        instance=np.array(instance)
        instance=preds(instance)
        predictions=model.predict(instance)
        ind=np.argpartition(predictions[0],-3)[-3:][::-1]
        for j in ind:
            suggestions.append(hero_dict[j])
        if label in suggestions:
            correct+=1
    print("Accuracy is ",correct/data.shape[0])

# %%
accuracy_computing(names_array[test_start:])
# Out:
# Accuracy is  0.09754901960784314

# %%
embed_df.head()
# Out:
#                        0         1         2         3         4         5  \
# Heroes
# Anti-Mage       0.305056 -0.805489  1.121158 -0.141986  0.946794  1.347950
# Axe             0.228642  0.858149 -0.514170  0.602047 -0.464758 -0.336470
# Bane            0.434433  0.015649  0.842300 -0.048546 -0.350595 -0.278436
# Bloodseeker     0.481227  0.338672  0.370381  0.220712 -0.231627 -0.272621
# Crystal Maiden  0.465281 -0.219395  0.984966 -0.343826 -0.423050 -0.243807
#
#                        6         7         8         9  ...        15  \
# Heroes                                                  ...
# Anti-Mage       0.258835 -0.113208  0.465853 -0.427102  ...  0.784361
# Axe            -0.042451 -0.074548 -0.046774 -0.557308  ...  0.954994
# Bane           -0.284187  1.025200 -0.605541  0.202381  ...  0.625897
# Bloodseeker     0.326090 -0.009944  0.052213 -0.211072  ...  0.968901
# Crystal Maiden -0.128838  1.024566 -0.758725  0.398168  ...  0.616749
#
#                       16        17        18        19        20        21  \
# Heroes
# Anti-Mage      -0.060602  0.200479  0.327247 -0.568588  0.301570  0.169598
# Axe             0.601367  0.595055 -0.545509 -0.745396  0.616176  1.081884
# Bane           -0.522461  0.230606 -0.269472 -0.183916 -0.782461 -0.137054
# Bloodseeker     0.223838 -0.256637 -0.106540 -0.468865  0.310433  0.608026
# Crystal Maiden -0.504094 -0.044536 -0.062153 -0.015833 -0.796932 -0.519311
#
#                       22        23        24
# Heroes
# Anti-Mage       0.386424  0.607690  0.669263
# Axe             0.190573  0.105106  0.219873
# Bane           -0.172839 -0.522343 -0.241623
# Bloodseeker     0.157200 -0.029146  0.099427
# Crystal Maiden  0.098114 -0.462588 -0.265883
#
# [5 rows x 25 columns]
